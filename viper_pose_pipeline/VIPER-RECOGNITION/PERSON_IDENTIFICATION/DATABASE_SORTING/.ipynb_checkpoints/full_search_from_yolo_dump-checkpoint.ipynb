# %%
import import_ipynb
from store_temp_people import *
import pickle
# Out:
# importing Jupyter notebook from store_temp_people.ipynb
# Found 0
# [58.60289, 39.386696, 89.6731, 54.086338, 101.2653, 24.845522, 57.25623, 38.184544, 49.882946, 88.968666, 56.675037, 70.74721]
# [21.484955, 31.139622, 57.868084, 0, 57.905758, 26.51006, 0, 13.335337, 41.6424, 41.95069, 42.52827, 40.93839]
# 3
# Found 0
# [4.878723, 52.555344, 86.21472, 53.03556, 86.773766, 37.36194, 42.14236, 3.39322, 58.900974, 59.697777, 58.67777, 49.63518]
# [21.484955, 31.139622, 57.868084, 0, 57.905758, 26.51006, 0, 13.335337, 41.6424, 41.95069, 42.52827, 40.93839]
# 3
# [4.878723, 52.555344, 86.21472, 53.03556, 86.773766, 37.36194, 42.14236, 3.39322, 58.900974, 59.697777, 58.67777, 49.63518]
# [58.60289, 0, 89.6731, 54.086338, 101.2653, 0, 57.25623, 38.184544, 49.882946, 88.968666, 56.675037, 70.74721]
# 3
# Found 0
# [6.6085663, 13.337214, 55.116905, 15.969656, 52.690216, 10.383776, 22.35487, 5.953518, 49.642967, 56.69619, 79.44664, 83.60015]
# ...

# %%
with open("../YOLOV8/frames_data.pkl","rb") as f:
    dat=pickle.load(f)

# %%
frames=[]
count=0
for i in range(len(dat[0])):
    frames.append(Frame_data(str(count),dat[0][i],dat[1][i],dat[1][i],dat[2][i],'daytime'))
    count=count+1

# %%
for i in range(len(frames)):
    temp_people_list=sort_frame_data(frames[i],temp_people_list,soft_similarity_threshold,hard_similarity_threshold,maturity_threshold,global_vec_threshold,global_face_threshold,secondary_euclidean_threshold,global_search_percentage)

# %%
# Out:
# 20

# %%
temp_people_list[2].all_data
# Out:
# [[62.488495, 86.00896, 80.68546],
#  [58.253468, 106.56008],
#  [85.933464, 121.45548, 96.38179],
#  [53.407948, 80.21374, 66.74742],
#  [97.80732, 125.117485, 112.42639],
#  [54.102764, 29.751766],
#  [56.650787, 67.609604],
#  [39.953747, 57.196407, 57.267265],
#  [51.644165, 82.8785, 140.61913],
#  [89.02293, 95.80803, 139.68922],
#  [56.98844, 84.79337, 101.502815],
#  [71.930145, 76.29457, 98.47159]]
