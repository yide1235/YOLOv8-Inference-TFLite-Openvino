# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/Colab Notebooks/VIPER-RECOGNITION/
# Out:
# /content/drive/MyDrive/Colab Notebooks/VIPER-RECOGNITION

# %%
cd PERSON_IDENTIFICATION
# Out:
# /content/drive/MyDrive/Colab Notebooks/VIPER-RECOGNITION/PERSON_IDENTIFICATION

# %%
ls
# Out:
# 3969-0.jpg         DATABASE_SORTING/         test_3969-_.jpg       tmp_l.jpg
# 3969_stereo-0.jpg  LINE_MATCHING/            test_rectified_l.jpg  tmp_r.jpg
# box_l.jpg          model_input.jpg           test_rectified_r.jpg  TRIANGULATION/
# box_r.jpg          person_identification.py  THUNDER/              YOLOV8/

# %%
pip install tflite_runtime
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 22.0 MB/s eta 0:00:00
# ...

# %%
# !chmod +rw ./

# %%
# !python person_identification.py
# Out:
# 2023-11-06 04:22:29.169787: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-06 04:22:29.169859: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-06 04:22:29.169903: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-06 04:22:29.179851: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
